# %% [markdown]
# Q-6. A pharmaceutical company is developing a drug that is supposed to reduce blood
# pressure. They conduct a clinical trial with 100 patients and record their blood
# pressure before and after taking the drug. The company wants to know if the change
# in blood pressure follows a normal distribution.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/data.csv')

# %%
df.columns
# Out:
# Index(['Patient ID', ' Blood Pressure Before (mmHg)',
#        ' Blood Pressure After (mmHg)'],
#       dtype='object')

# %%
df['Change in Blood Pressure'] = df[' Blood Pressure Before (mmHg)'] - df[' Blood Pressure After (mmHg)']

# %%
plt.hist(df['Change in Blood Pressure'], bins=10, edgecolor='black')
plt.xlabel('Change in Blood Pressure')
plt.ylabel('Frequency')
plt.title('Distribution of Change in Blood Pressure')
plt.show()

# %%
# Plotting histogram and KDE
sns.histplot(data=df, x='Change in Blood Pressure', bins=10, kde=True, edgecolor='black')

plt.xlabel('Change in Blood Pressure')
plt.ylabel('Frequency')
plt.title('Distribution of Change in Blood Pressure')

plt.show()

# %% [markdown]
# By visualizing the histogram, we can assess whether the change in blood pressure data approximately follows a normal distribution.
