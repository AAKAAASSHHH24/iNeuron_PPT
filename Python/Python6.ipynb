# %% [markdown]
# Using the data from Question 3, write code to analyze the data and answer the following questions Note 1.
# Draw plots to demonstrate the analysis for the following questions for better visualizations.
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
#
# ● Get all Pokemons whose spawn rate is less than 5%
#
# ● Get all Pokemons that have less than 4 weaknesses
#
# ● Get all Pokemons that have no multipliers at all
#
# ● Get all Pokemons that do not have more than 2 evolutions
#
# ● Get all Pokemons whose spawn time is less than 300 seconds.
#
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
#
# ● Get all Pokemon who have more than two types of capabilities

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

def download_data(url):
    response = requests.get(url)  # Send a GET request to the URL
    data = response.json()  # Get the JSON data from the response
    return data

def convert_to_dataframe(data):
    # Create a DataFrame from the data
    df = pd.DataFrame(data["pokemon"])

    return df

def analyze_data(df):
    # Get all Pokemons whose spawn rate is less than 5%
    spawn_rate_less_than_5 = df[df["spawn_chance"] < 5]
    
    # Get all Pokemons that have less than 4 weaknesses
    less_than_4_weaknesses = df[df["weaknesses"].apply(len) < 4]
    
    # Get all Pokemons that have no multipliers at all
    no_multipliers = df[df["multipliers"].apply(len) == 0]
    
    # Get all Pokemons that do not have more than 2 evolutions
    less_than_2_evolutions = df[df["next_evolution"].apply(len) < 3]
    
    # Get all Pokemons whose spawn time is less than 300 seconds
    df["spawn_time_seconds"] = df["spawn_time"].apply(lambda x: int(x.split(":")[0]) * 60 + int(x.split(":")[1]))
    spawn_time_less_than_300 = df[df["spawn_time_seconds"] < 300]
    
    # Get all Pokemon who have more than two types of capabilities
    more_than_2_types = df[df["type"].apply(len) > 2]
    
    return spawn_rate_less_than_5, less_than_4_weaknesses, no_multipliers, less_than_2_evolutions, spawn_time_less_than_300, more_than_2_types

def plot_analysis(spawn_rate_less_than_5, less_than_4_weaknesses, no_multipliers, less_than_2_evolutions, spawn_time_less_than_300, more_than_2_types):
    # Plotting the analysis results
    plt.figure(figsize=(12, 8))
    
    # Plot 1: Pokemons whose spawn rate is less than 5%
    plt.subplot(231)
    plt.title("Pokemons with Spawn Rate < 5%")
    spawn_rate_less_than_5["spawn_chance"].hist()
    plt.xlabel("Spawn Rate (%)")
    plt.ylabel("Count")
    
    # Plot 2: Pokemons that have less than 4 weaknesses
    plt.subplot(232)
    plt.title("Pokemons with Less than 4 Weaknesses")
    less_than_4_weaknesses["weaknesses"].apply(len).hist()
    plt.xlabel("Number of Weaknesses")
    plt.ylabel("Count")
    
    # Plot 3: Pokemons that have no multipliers at all
    plt.subplot(233)
    plt.title("Pokemons with No Multipliers")
    no_multipliers["multipliers"].apply(len).hist()
    plt.xlabel("Number of Multipliers")
    plt.ylabel("Count")
    
    # Plot 4: Pokemons that do not have more than 2 evolutions
    plt.subplot(234)
    plt.title("Pokemons with Less than 2 Evolutions")
    less_than_2_evolutions["next_evolution"].apply(len).hist()
    plt.xlabel("Number of Evolutions")
    plt.ylabel("Count")
    
    #

# %%
# Provide the URL of the data
url = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"

# Download the data
data = download_data(url)

# Convert the data into a DataFrame
df = convert_to_dataframe(data)
df.dropna(inplace= True)

# Analyze the data
spawn_rate_less_than_5, less_than_4_weaknesses, no_multipliers, less_than_2_evolutions, spawn_time_less_than_300, more_than_2_types = analyze_data(df)

# Print the results
print("Pokemons with Spawn Rate < 5%:")
print(spawn_rate_less_than_5)
print()

print("Pokemons with Less than 4 Weaknesses:")
print(less_than_4_weaknesses)
print()

print("Pokemons with No Multipliers:")
print(no_multipliers)
print()

print("Pokemons with Less than 2 Evolutions:")
print(less_than_2_evolutions)
print()

print("Pokemons with Spawn Time < 300 seconds:")
print(spawn_time_less_than_300)
print()

print("Pokemons with More than 2 Types:")
print(more_than_2_types)
# Out:
# Pokemons with Spawn Rate < 5%:
#       id  num        name                                               img  \
# 1      2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 4      5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 7      8  008   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 10    11  011     Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 13    14  014      Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# 16    17  017   Pidgeotto  http://www.serebii.net/pokemongo/pokemon/017.png
# 29    30  030    Nidorina  http://www.serebii.net/pokemongo/pokemon/030.png
# 32    33  033    Nidorino  http://www.serebii.net/pokemongo/pokemon/033.png
# 43    44  044       Gloom  http://www.serebii.net/pokemongo/pokemon/044.png
# 60    61  061   Poliwhirl  http://www.serebii.net/pokemongo/pokemon/061.png
# 63    64  064     Kadabra  http://www.serebii.net/pokemongo/pokemon/064.png
# 66    67  067     Machoke  http://www.serebii.net/pokemongo/pokemon/067.png
# 69    70  070  Weepinbell  http://www.serebii.net/pokemongo/pokemon/070.png
# 74    75  075    Graveler  http://www.serebii.net/pokemongo/pokemon/075.png
# 92    93  093     Haunter  http://www.serebii.net/pokemongo/pokemon/093.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
#
#                  type  height    weight                     candy  \
# 1     [Grass, Poison]  0.99 m   13.0 kg           Bulbasaur Candy
# 4              [Fire]  1.09 m   19.0 kg          Charmander Candy
# 7             [Water]  0.99 m   22.5 kg            Squirtle Candy
# 10              [Bug]  0.71 m    9.9 kg            Caterpie Candy
# 13      [Bug, Poison]  0.61 m   10.0 kg              Weedle Candy
# 16   [Normal, Flying]  1.09 m   30.0 kg              Pidgey Candy
# 29           [Poison]  0.79 m   20.0 kg  Nidoran ♀ (Female) Candy
# 32           [Poison]  0.89 m   19.5 kg    Nidoran ♂ (Male) Candy
# 43    [Grass, Poison]  0.79 m    8.6 kg              Oddish Candy
# 60            [Water]  0.99 m   20.0 kg             Poliwag Candy
# 63          [Psychic]  1.30 m   56.5 kg                Abra Candy
# 66         [Fighting]  1.50 m   70.5 kg              Machop Candy
# 69    [Grass, Poison]  0.99 m    6.4 kg          Bellsprout Candy
# 74     [Rock, Ground]  0.99 m  105.0 kg             Geodude Candy
# 92    [Ghost, Poison]  1.60 m    0.1 kg              Gastly Candy
# 147          [Dragon]  3.99 m   16.5 kg             Dratini Candy
#
#      candy_count          egg  spawn_chance  avg_spawns spawn_time  \
# 1          100.0  Not in Eggs         0.042         4.2      07:00
# 4          100.0  Not in Eggs         0.012         1.2      19:00
# 7          100.0  Not in Eggs         0.034         3.4      07:02
# 10          50.0  Not in Eggs         0.187        18.7      02:11
# 13          50.0  Not in Eggs         0.440        44.0      02:30
# 16          50.0  Not in Eggs         1.020       102.0      01:30
# 29         100.0  Not in Eggs         0.088         8.8      07:22
# 32         100.0  Not in Eggs         0.083         8.3      09:02
# 43         100.0  Not in Eggs         0.064         6.4      11:33
# 60         100.0  Not in Eggs         0.130        13.0      09:14
# 63         100.0  Not in Eggs         0.027         2.7      11:25
# 66         100.0  Not in Eggs         0.034         3.4      10:32
# 69         100.0  Not in Eggs         0.072         7.2      09:45
# 74         100.0  Not in Eggs         0.071         7.1      04:53
# 92         100.0  Not in Eggs         0.052         5.2      00:10
# 147        100.0  Not in Eggs         0.020         2.0      11:57
#
#       multipliers                                    weaknesses  \
# 1      [1.2, 1.6]                  [Fire, Ice, Flying, Psychic]
# 4          [1.79]                         [Water, Ground, Rock]
# 7           [1.4]                             [Electric, Grass]
# 10   [3.55, 3.79]                          [Fire, Flying, Rock]
# 13   [3.01, 3.41]                 [Fire, Flying, Psychic, Rock]
# 16         [1.79]                              [Electric, Rock]
# 29   [1.83, 2.48]                             [Ground, Psychic]
# 32         [1.83]                             [Ground, Psychic]
# 43         [1.49]                  [Fire, Ice, Flying, Psychic]
# 60         [1.95]                             [Electric, Grass]
# 63          [1.4]                            [Bug, Ghost, Dark]
# 66          [1.7]                      [Flying, Psychic, Fairy]
# 69         [1.59]                  [Fire, Ice, Flying, Psychic]
# 74   [1.64, 1.72]  [Water, Grass, Ice, Fighting, Ground, Steel]
# 92    [1.56, 1.8]                [Ground, Psychic, Ghost, Dark]
# 147        [2.05]                          [Ice, Dragon, Fairy]
#
#                              next_evolution  \
# 1      [{'num': '003', 'name': 'Venusaur'}]
# 4     [{'num': '006', 'name': 'Charizard'}]
# 7     [{'num': '009', 'name': 'Blastoise'}]
# 10   [{'num': '012', 'name': 'Butterfree'}]
# 13     [{'num': '015', 'name': 'Beedrill'}]
# 16      [{'num': '018', 'name': 'Pidgeot'}]
# 29    [{'num': '031', 'name': 'Nidoqueen'}]
# 32     [{'num': '034', 'name': 'Nidoking'}]
# 43    [{'num': '045', 'name': 'Vileplume'}]
# 60    [{'num': '062', 'name': 'Poliwrath'}]
# 63     [{'num': '065', 'name': 'Alakazam'}]
# 66      [{'num': '068', 'name': 'Machamp'}]
# 69   [{'num': '071', 'name': 'Victreebel'}]
# 74        [{'num': '076', 'name': 'Golem'}]
# 92       [{'num': '094', 'name': 'Gengar'}]
# 147   [{'num': '149', 'name': 'Dragonite'}]
#
#                                   prev_evolution
# 1          [{'num': '001', 'name': 'Bulbasaur'}]
# 4         [{'num': '004', 'name': 'Charmander'}]
# 7           [{'num': '007', 'name': 'Squirtle'}]
# 10          [{'num': '010', 'name': 'Caterpie'}]
# 13            [{'num': '013', 'name': 'Weedle'}]
# 16            [{'num': '016', 'name': 'Pidgey'}]
# 29   [{'num': '029', 'name': 'Nidoran(Female)'}]
# 32     [{'num': '032', 'name': 'Nidoran(Male)'}]
# 43            [{'num': '043', 'name': 'Oddish'}]
# 60           [{'num': '060', 'name': 'Poliwag'}]
# 63              [{'num': '063', 'name': 'Abra'}]
# 66            [{'num': '066', 'name': 'Machop'}]
# 69        [{'num': '069', 'name': 'Bellsprout'}]
# 74           [{'num': '074', 'name': 'Geodude'}]
# 92            [{'num': '092', 'name': 'Gastly'}]
# 147          [{'num': '147', 'name': 'Dratini'}]
#
# Pokemons with Less than 4 Weaknesses:
#       id  num        name                                               img  \
# 4      5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 7      8  008   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 10    11  011     Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 16    17  017   Pidgeotto  http://www.serebii.net/pokemongo/pokemon/017.png
# 29    30  030    Nidorina  http://www.serebii.net/pokemongo/pokemon/030.png
# 32    33  033    Nidorino  http://www.serebii.net/pokemongo/pokemon/033.png
# 60    61  061   Poliwhirl  http://www.serebii.net/pokemongo/pokemon/061.png
# 63    64  064     Kadabra  http://www.serebii.net/pokemongo/pokemon/064.png
# 66    67  067     Machoke  http://www.serebii.net/pokemongo/pokemon/067.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
#
#                  type  height   weight                     candy  candy_count  \
# 4              [Fire]  1.09 m  19.0 kg          Charmander Candy        100.0
# 7             [Water]  0.99 m  22.5 kg            Squirtle Candy        100.0
# 10              [Bug]  0.71 m   9.9 kg            Caterpie Candy         50.0
# 16   [Normal, Flying]  1.09 m  30.0 kg              Pidgey Candy         50.0
# 29           [Poison]  0.79 m  20.0 kg  Nidoran ♀ (Female) Candy        100.0
# 32           [Poison]  0.89 m  19.5 kg    Nidoran ♂ (Male) Candy        100.0
# 60            [Water]  0.99 m  20.0 kg             Poliwag Candy        100.0
# 63          [Psychic]  1.30 m  56.5 kg                Abra Candy        100.0
# 66         [Fighting]  1.50 m  70.5 kg              Machop Candy        100.0
# 147          [Dragon]  3.99 m  16.5 kg             Dratini Candy        100.0
#
#              egg  spawn_chance  avg_spawns spawn_time   multipliers  \
# 4    Not in Eggs         0.012         1.2      19:00        [1.79]
# 7    Not in Eggs         0.034         3.4      07:02         [1.4]
# 10   Not in Eggs         0.187        18.7      02:11  [3.55, 3.79]
# 16   Not in Eggs         1.020       102.0      01:30        [1.79]
# 29   Not in Eggs         0.088         8.8      07:22  [1.83, 2.48]
# 32   Not in Eggs         0.083         8.3      09:02        [1.83]
# 60   Not in Eggs         0.130        13.0      09:14        [1.95]
# 63   Not in Eggs         0.027         2.7      11:25         [1.4]
# 66   Not in Eggs         0.034         3.4      10:32         [1.7]
# 147  Not in Eggs         0.020         2.0      11:57        [2.05]
#
#                    weaknesses                          next_evolution  \
# 4       [Water, Ground, Rock]   [{'num': '006', 'name': 'Charizard'}]
# 7           [Electric, Grass]   [{'num': '009', 'name': 'Blastoise'}]
# 10       [Fire, Flying, Rock]  [{'num': '012', 'name': 'Butterfree'}]
# 16           [Electric, Rock]     [{'num': '018', 'name': 'Pidgeot'}]
# 29          [Ground, Psychic]   [{'num': '031', 'name': 'Nidoqueen'}]
# 32          [Ground, Psychic]    [{'num': '034', 'name': 'Nidoking'}]
# 60          [Electric, Grass]   [{'num': '062', 'name': 'Poliwrath'}]
# 63         [Bug, Ghost, Dark]    [{'num': '065', 'name': 'Alakazam'}]
# 66   [Flying, Psychic, Fairy]     [{'num': '068', 'name': 'Machamp'}]
# 147      [Ice, Dragon, Fairy]   [{'num': '149', 'name': 'Dragonite'}]
#
#                                   prev_evolution
# 4         [{'num': '004', 'name': 'Charmander'}]
# 7           [{'num': '007', 'name': 'Squirtle'}]
# 10          [{'num': '010', 'name': 'Caterpie'}]
# 16            [{'num': '016', 'name': 'Pidgey'}]
# 29   [{'num': '029', 'name': 'Nidoran(Female)'}]
# 32     [{'num': '032', 'name': 'Nidoran(Male)'}]
# 60           [{'num': '060', 'name': 'Poliwag'}]
# 63              [{'num': '063', 'name': 'Abra'}]
# 66            [{'num': '066', 'name': 'Machop'}]
# 147          [{'num': '147', 'name': 'Dratini'}]
#
# Pokemons with No Multipliers:
# Empty DataFrame
# Columns: [id, num, name, img, type, height, weight, candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, weaknesses, next_evolution, prev_evolution]
# Index: []
#
# Pokemons with Less than 2 Evolutions:
#       id  num        name                                               img  \
# 1      2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 4      5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 7      8  008   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 10    11  011     Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 13    14  014      Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# 16    17  017   Pidgeotto  http://www.serebii.net/pokemongo/pokemon/017.png
# 29    30  030    Nidorina  http://www.serebii.net/pokemongo/pokemon/030.png
# 32    33  033    Nidorino  http://www.serebii.net/pokemongo/pokemon/033.png
# 43    44  044       Gloom  http://www.serebii.net/pokemongo/pokemon/044.png
# 60    61  061   Poliwhirl  http://www.serebii.net/pokemongo/pokemon/061.png
# 63    64  064     Kadabra  http://www.serebii.net/pokemongo/pokemon/064.png
# 66    67  067     Machoke  http://www.serebii.net/pokemongo/pokemon/067.png
# 69    70  070  Weepinbell  http://www.serebii.net/pokemongo/pokemon/070.png
# 74    75  075    Graveler  http://www.serebii.net/pokemongo/pokemon/075.png
# 92    93  093     Haunter  http://www.serebii.net/pokemongo/pokemon/093.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
#
#                  type  height    weight                     candy  \
# 1     [Grass, Poison]  0.99 m   13.0 kg           Bulbasaur Candy
# 4              [Fire]  1.09 m   19.0 kg          Charmander Candy
# 7             [Water]  0.99 m   22.5 kg            Squirtle Candy
# 10              [Bug]  0.71 m    9.9 kg            Caterpie Candy
# 13      [Bug, Poison]  0.61 m   10.0 kg              Weedle Candy
# 16   [Normal, Flying]  1.09 m   30.0 kg              Pidgey Candy
# 29           [Poison]  0.79 m   20.0 kg  Nidoran ♀ (Female) Candy
# 32           [Poison]  0.89 m   19.5 kg    Nidoran ♂ (Male) Candy
# 43    [Grass, Poison]  0.79 m    8.6 kg              Oddish Candy
# 60            [Water]  0.99 m   20.0 kg             Poliwag Candy
# 63          [Psychic]  1.30 m   56.5 kg                Abra Candy
# 66         [Fighting]  1.50 m   70.5 kg              Machop Candy
# 69    [Grass, Poison]  0.99 m    6.4 kg          Bellsprout Candy
# 74     [Rock, Ground]  0.99 m  105.0 kg             Geodude Candy
# 92    [Ghost, Poison]  1.60 m    0.1 kg              Gastly Candy
# 147          [Dragon]  3.99 m   16.5 kg             Dratini Candy
#
#      candy_count          egg  spawn_chance  avg_spawns spawn_time  \
# 1          100.0  Not in Eggs         0.042         4.2      07:00
# 4          100.0  Not in Eggs         0.012         1.2      19:00
# 7          100.0  Not in Eggs         0.034         3.4      07:02
# 10          50.0  Not in Eggs         0.187        18.7      02:11
# 13          50.0  Not in Eggs         0.440        44.0      02:30
# 16          50.0  Not in Eggs         1.020       102.0      01:30
# 29         100.0  Not in Eggs         0.088         8.8      07:22
# 32         100.0  Not in Eggs         0.083         8.3      09:02
# 43         100.0  Not in Eggs         0.064         6.4      11:33
# 60         100.0  Not in Eggs         0.130        13.0      09:14
# 63         100.0  Not in Eggs         0.027         2.7      11:25
# 66         100.0  Not in Eggs         0.034         3.4      10:32
# 69         100.0  Not in Eggs         0.072         7.2      09:45
# 74         100.0  Not in Eggs         0.071         7.1      04:53
# 92         100.0  Not in Eggs         0.052         5.2      00:10
# 147        100.0  Not in Eggs         0.020         2.0      11:57
#
#       multipliers                                    weaknesses  \
# 1      [1.2, 1.6]                  [Fire, Ice, Flying, Psychic]
# 4          [1.79]                         [Water, Ground, Rock]
# 7           [1.4]                             [Electric, Grass]
# 10   [3.55, 3.79]                          [Fire, Flying, Rock]
# 13   [3.01, 3.41]                 [Fire, Flying, Psychic, Rock]
# 16         [1.79]                              [Electric, Rock]
# 29   [1.83, 2.48]                             [Ground, Psychic]
# 32         [1.83]                             [Ground, Psychic]
# 43         [1.49]                  [Fire, Ice, Flying, Psychic]
# 60         [1.95]                             [Electric, Grass]
# 63          [1.4]                            [Bug, Ghost, Dark]
# 66          [1.7]                      [Flying, Psychic, Fairy]
# 69         [1.59]                  [Fire, Ice, Flying, Psychic]
# 74   [1.64, 1.72]  [Water, Grass, Ice, Fighting, Ground, Steel]
# 92    [1.56, 1.8]                [Ground, Psychic, Ghost, Dark]
# 147        [2.05]                          [Ice, Dragon, Fairy]
#
#                              next_evolution  \
# 1      [{'num': '003', 'name': 'Venusaur'}]
# 4     [{'num': '006', 'name': 'Charizard'}]
# 7     [{'num': '009', 'name': 'Blastoise'}]
# 10   [{'num': '012', 'name': 'Butterfree'}]
# 13     [{'num': '015', 'name': 'Beedrill'}]
# 16      [{'num': '018', 'name': 'Pidgeot'}]
# 29    [{'num': '031', 'name': 'Nidoqueen'}]
# 32     [{'num': '034', 'name': 'Nidoking'}]
# 43    [{'num': '045', 'name': 'Vileplume'}]
# 60    [{'num': '062', 'name': 'Poliwrath'}]
# 63     [{'num': '065', 'name': 'Alakazam'}]
# 66      [{'num': '068', 'name': 'Machamp'}]
# 69   [{'num': '071', 'name': 'Victreebel'}]
# 74        [{'num': '076', 'name': 'Golem'}]
# 92       [{'num': '094', 'name': 'Gengar'}]
# 147   [{'num': '149', 'name': 'Dragonite'}]
#
#                                   prev_evolution
# 1          [{'num': '001', 'name': 'Bulbasaur'}]
# 4         [{'num': '004', 'name': 'Charmander'}]
# 7           [{'num': '007', 'name': 'Squirtle'}]
# 10          [{'num': '010', 'name': 'Caterpie'}]
# 13            [{'num': '013', 'name': 'Weedle'}]
# 16            [{'num': '016', 'name': 'Pidgey'}]
# 29   [{'num': '029', 'name': 'Nidoran(Female)'}]
# 32     [{'num': '032', 'name': 'Nidoran(Male)'}]
# 43            [{'num': '043', 'name': 'Oddish'}]
# 60           [{'num': '060', 'name': 'Poliwag'}]
# 63              [{'num': '063', 'name': 'Abra'}]
# 66            [{'num': '066', 'name': 'Machop'}]
# 69        [{'num': '069', 'name': 'Bellsprout'}]
# 74           [{'num': '074', 'name': 'Geodude'}]
# 92            [{'num': '092', 'name': 'Gastly'}]
# 147          [{'num': '147', 'name': 'Dratini'}]
#
# Pokemons with Spawn Time < 300 seconds:
#     id  num       name                                               img  \
# 10  11  011    Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 13  14  014     Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# 16  17  017  Pidgeotto  http://www.serebii.net/pokemongo/pokemon/017.png
# 74  75  075   Graveler  http://www.serebii.net/pokemongo/pokemon/075.png
# 92  93  093    Haunter  http://www.serebii.net/pokemongo/pokemon/093.png
#
#                 type  height    weight           candy  candy_count  \
# 10             [Bug]  0.71 m    9.9 kg  Caterpie Candy         50.0
# 13     [Bug, Poison]  0.61 m   10.0 kg    Weedle Candy         50.0
# 16  [Normal, Flying]  1.09 m   30.0 kg    Pidgey Candy         50.0
# 74    [Rock, Ground]  0.99 m  105.0 kg   Geodude Candy        100.0
# 92   [Ghost, Poison]  1.60 m    0.1 kg    Gastly Candy        100.0
#
#             egg  spawn_chance  avg_spawns spawn_time   multipliers  \
# 10  Not in Eggs         0.187        18.7      02:11  [3.55, 3.79]
# 13  Not in Eggs         0.440        44.0      02:30  [3.01, 3.41]
# 16  Not in Eggs         1.020       102.0      01:30        [1.79]
# 74  Not in Eggs         0.071         7.1      04:53  [1.64, 1.72]
# 92  Not in Eggs         0.052         5.2      00:10   [1.56, 1.8]
#
#                                       weaknesses  \
# 10                          [Fire, Flying, Rock]
# 13                 [Fire, Flying, Psychic, Rock]
# 16                              [Electric, Rock]
# 74  [Water, Grass, Ice, Fighting, Ground, Steel]
# 92                [Ground, Psychic, Ghost, Dark]
#
#                             next_evolution  \
# 10  [{'num': '012', 'name': 'Butterfree'}]
# 13    [{'num': '015', 'name': 'Beedrill'}]
# 16     [{'num': '018', 'name': 'Pidgeot'}]
# 74       [{'num': '076', 'name': 'Golem'}]
# 92      [{'num': '094', 'name': 'Gengar'}]
#
#                           prev_evolution  spawn_time_seconds
# 10  [{'num': '010', 'name': 'Caterpie'}]                 131
# 13    [{'num': '013', 'name': 'Weedle'}]                 150
# 16    [{'num': '016', 'name': 'Pidgey'}]                  90
# 74   [{'num': '074', 'name': 'Geodude'}]                 293
# 92    [{'num': '092', 'name': 'Gastly'}]                  10
#
# Pokemons with More than 2 Types:
# Empty DataFrame
# Columns: [id, num, name, img, type, height, weight, candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, weaknesses, next_evolution, prev_evolution, spawn_time_seconds]
# Index: []
